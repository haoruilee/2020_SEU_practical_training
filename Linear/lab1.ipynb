# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler
import time

# %%
#panda加载csv文件
data = pd.read_csv('data_stocks.csv')
#查看总览信息，最大值最小值均值
data.describe()
# Out:
#                DATE         SP500    NASDAQ.AAL   NASDAQ.AAPL  NASDAQ.ADBE  \
# count  4.126600e+04  41266.000000  41266.000000  41266.000000  41266.00000
# mean   1.497749e+09   2421.537882     47.708346    150.453566    141.31793
# std    3.822211e+06     39.557135      3.259377      6.236826      6.91674
# min    1.491226e+09   2329.139900     40.830000    140.160000    128.24000
# 25%    1.494432e+09   2390.860100     44.945400    144.640000    135.19500
# 50%    1.497638e+09   2430.149900     48.360000    149.945000    142.26000
# 75%    1.501090e+09   2448.820100     50.180000    155.065000    147.10000
# max    1.504210e+09   2490.649900     54.475000    164.510000    155.33000
#
#          NASDAQ.ADI    NASDAQ.ADP   NASDAQ.ADSK   NASDAQ.AKAM   NASDAQ.ALXN  \
# count  41266.000000  41266.000000  41266.000000  41266.000000  41266.000000
# mean      79.446873    103.480398    102.998608     50.894352    122.981163
# std        2.000283      4.424244      9.389788      4.833931     11.252010
# min       74.800000     95.870000     83.000000     44.650000     96.250000
# 25%       78.030000    101.300000     94.820000     47.440000    116.950000
# 50%       79.410000    102.440000    106.820000     49.509900    123.620000
# 75%       80.580000    104.660000    110.490000     52.230000    132.218800
# max       90.440000    121.770000    119.270000     62.560000    142.875000
#
#            ...           NYSE.WYN      NYSE.XEC      NYSE.XEL       NYSE.XL  \
# count      ...       41266.000000  41266.000000  41266.000000  41266.000000
# mean       ...          97.942211    104.740666     46.664402     43.043984
# std        ...           5.411795     10.606694      1.508444      1.714533
# min        ...          83.410000     89.510000     44.090000     39.120000
# 25%        ...          95.960000     95.010000     45.155000     41.955000
# 50%        ...          99.250000     99.660000     46.810000     43.200000
# 75%        ...         102.080000    117.034700     47.730000     44.370000
# max        ...         106.375000    123.870000     49.660000     47.210000
#
#            NYSE.XOM      NYSE.XRX      NYSE.XYL      NYSE.YUM      NYSE.ZBH  \
# count  41266.000000  41266.000000  41266.000000  41266.000000  41266.000000
# mean      80.784595     19.300718     54.541988     71.757891    121.423515
# std        1.840989     11.686532      3.526321      4.038272      5.607070
# min       76.060000      6.660000     48.820000     63.180000    110.120000
# 25%       80.220000      7.045000     51.630000     69.110000    117.580000
# 50%       81.150000     27.890000     53.850000     73.470000    120.650000
# 75%       82.062050     30.470000     57.140000     74.750000    126.000000
# max       83.630000     32.930000     62.130000     77.120000    133.450000
#
#            NYSE.ZTS
# count  41266.000000
# mean      60.183874
# std        3.346887
# min       52.300000
# 25%       59.620000
# 50%       61.585600
# 75%       62.540000
# max       63.840000
#
# [8 rows x 502 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41266 entries, 0 to 41265
# Columns: 502 entries, DATE to NYSE.ZTS
# dtypes: float64(501), int64(1)
# memory usage: 158.0 MB

# %%
print(time.strftime('%Y-%m-%d',time.localtime(data['DATE'].min())))
print(time.strftime('%Y-%m-%d',time.localtime(data['DATE'].max())))
# Out:
# 2017-04-03
# 2017-09-01

# %%
#打印出来大盘指数的变化趋势
plt.plot(data['SP500'])

# %%
#删除时间戳列
data.drop('DATE',axis=1,inplace=True)
data.head()
# Out:
#        SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  \
# 0  2363.6101     42.3300     143.6800     129.6300      82.040    102.2300
# 1  2364.1001     42.3600     143.7000     130.3200      82.080    102.1400
# 2  2362.6799     42.3100     143.6901     130.2250      82.030    102.2125
# 3  2364.3101     42.3700     143.6400     130.0729      82.000    102.1400
# 4  2364.8501     42.5378     143.6600     129.8800      82.035    102.0600
#
#    NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT    ...     NYSE.WYN  \
# 0      85.2200       59.760       121.52        38.99    ...       84.370
# 1      85.6500       59.840       121.48        39.01    ...       84.370
# 2      85.5100       59.795       121.93        38.91    ...       84.585
# 3      85.4872       59.620       121.44        38.84    ...       84.460
# 4      85.7001       59.620       121.60        38.93    ...       84.470
#
#    NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  \
# 0   119.035     44.40    39.88     82.03      7.36     50.22     63.86
# 1   119.035     44.11    39.88     82.03      7.38     50.22     63.74
# 2   119.260     44.09    39.98     82.02      7.36     50.12     63.75
# 3   119.260     44.25    39.99     82.02      7.35     50.16     63.88
# 4   119.610     44.11    39.96     82.03      7.36     50.20     63.91
#
#    NYSE.ZBH  NYSE.ZTS
# 0   122.000    53.350
# 1   121.770    53.350
# 2   121.700    53.365
# 3   121.700    53.380
# 4   121.695    53.240
#
# [5 rows x 501 columns]

# %%
#将所有数据分成训练集和测试集
data_train = data.iloc[:int(data.shape[0]*0.8),:]
data_test = data.iloc[int(data.shape[0]*0.8):,:]
print(data_train.shape,data_test.shape)
# Out:
# (33012, 501) (8254, 501)

# %%
#进行归一化处理
scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(data_train)
data_train = scaler.transform(data_train)
data_test = scaler.transform(data_test)

# %%
#将训练数据分出输入和输出
X_train = data_train[:,1:]
y_train = data_train[:,0]
#将测试数据分为输入和输出
X_test =  data_test[:,1:]
y_test = data_test[:,0]

# %%
#定义各层层数
input_dim = X_train.shape[1]
hidden1 = 1024
hidden2 = 512
hidden3 = 256
hidden4 = 128
output_dim = 1

#定义批的大小
batch_size = 256
#定义跑多少轮
epochs = 10

#重置计算图（为了安全）
tf.reset_default_graph()

#定义输入层
X = tf.placeholder(shape=[None,input_dim],dtype=tf.float32)
Y = tf.placeholder(shape=[None],dtype=tf.float32)

#定义隐层变量
W1 = tf.get_variable('W1',[input_dim,hidden1],initializer=tf.contrib.layers.xavier_initializer(seed = 1))
b1 = tf.get_variable('b1',[hidden1],initializer=tf.zeros_initializer())

W2 = tf.get_variable('W2',[hidden1,hidden2],initializer=tf.contrib.layers.xavier_initializer(seed = 1))
b2 = tf.get_variable('b2',[hidden2],initializer=tf.zeros_initializer())

W3 = tf.get_variable('W3',[hidden2,hidden3],initializer=tf.contrib.layers.xavier_initializer(seed = 1))
b3 = tf.get_variable('b3',[hidden3],initializer=tf.zeros_initializer())

W4 = tf.get_variable('W4',[hidden3,hidden4],initializer=tf.contrib.layers.xavier_initializer(seed = 1))
b4 = tf.get_variable('b4',[hidden4],initializer=tf.zeros_initializer())

W5 = tf.get_variable('W5',[hidden4,output_dim],initializer=tf.contrib.layers.xavier_initializer(seed = 1))
b5 = tf.get_variable('b5',[output_dim],initializer=tf.zeros_initializer())

#定义logits回归
h1 = tf.nn.relu(tf.add(tf.matmul(X,W1),b1))
h2 = tf.nn.relu(tf.add(tf.matmul(h1,W2),b2))
h3 = tf.nn.relu(tf.add(tf.matmul(h2,W3),b3))
h4 = tf.nn.relu(tf.add(tf.matmul(h3,W4),b4))
out = tf.transpose(tf.add(tf.matmul(h4,W5),b5))

#定义损失
cost = tf.reduce_mean(tf.squared_difference(out,Y))
#定义优化方式
optimizer = tf.train.AdamOptimizer().minimize(cost)

# %%
#开始图的运行阶段
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for e in range(epochs):
        shuffle_indices = np.random.permutation(np.arange(y_train.shape[0]))
        X_train = X_train[shuffle_indices]
        y_train = y_train[shuffle_indices]
        
        for i in range(y_train.shape[0]//batch_size):
            start = i * batch_size
            batch_x = X_train[start : start + batch_size]
            batch_y = y_train[start: start + batch_size]
            
            sess.run(optimizer,feed_dict={X:batch_x,Y: batch_y})
            
#到此处图的定义及图的运行已完毕
            # 看训练的过程
            if i % 50 == 0:
                print("在训练集上的损失：",sess.run(cost,feed_dict={X:X_train,Y:y_train}))
                print("在测试集上的损失：",sess.run(cost,feed_dict={X:X_test,Y:y_test}))
                saver = tf.train.Saver()
                saver.save(sess, "./model.ckpt", meta_graph_suffix='meta', write_meta_graph=True)
                tf.train.write_graph(sess.graph_def, "./Model", "model.pb", False)
                #预测值
                y_pred = sess.run(out,feed_dict={X:X_test})
                y_pred = np.squeeze(y_pred)
                plt.plot(y_test,label = 'test')
                plt.plot(y_pred,label = 'pred')
                plt.title("这是第"+str(e) + "次循环的第"+str(i)+"批")
                plt.legend()
                plt.show()
# Out:
# 在训练集上的损失： 0.639846
# 在测试集上的损失： 1.24381
# 在训练集上的损失： 0.000503369
# 在测试集上的损失： 0.0134821
# 在训练集上的损失： 0.000539825
# 在测试集上的损失： 0.0129478
# 在训练集上的损失： 0.000161468
# 在测试集上的损失： 0.011662
# 在训练集上的损失： 0.000124311
# 在测试集上的损失： 0.0101212
# 在训练集上的损失： 0.00011391
# 在测试集上的损失： 0.00986246
# 在训练集上的损失： 0.000146374
# 在测试集上的损失： 0.00984738
# 在训练集上的损失： 9.75787e-05
# 在测试集上的损失： 0.00938842
# 在训练集上的损失： 0.000265384
# 在测试集上的损失： 0.00895785
# 在训练集上的损失： 0.000262687
# 在测试集上的损失： 0.00897958
# 在训练集上的损失： 7.49537e-05
# 在测试集上的损失： 0.00866116
# 在训练集上的损失： 7.85727e-05
# 在测试集上的损失： 0.00802215
# 在训练集上的损失： 8.96629e-05
# 在测试集上的损失： 0.00800419
# 在训练集上的损失： 9.45917e-05
# 在测试集上的损失： 0.00757297
# 在训练集上的损失： 9.56859e-05
# 在测试集上的损失： 0.00802125
# 在训练集上的损失： 9.82935e-05
# 在测试集上的损失： 0.00772668
# 在训练集上的损失： 0.000186335
# 在测试集上的损失： 0.0077956
# 在训练集上的损失： 8.23973e-05
# 在测试集上的损失： 0.00724629
# 在训练集上的损失： 8.85627e-05
# 在测试集上的损失： 0.00633013
# 在训练集上的损失： 6.54141e-05
# 在测试集上的损失： 0.00622303
# 在训练集上的损失： 8.45546e-05
# 在测试集上的损失： 0.00568062
# 在训练集上的损失： 0.000110022
# 在测试集上的损失： 0.00571869
# 在训练集上的损失： 7.07775e-05
# 在测试集上的损失： 0.00560945
# 在训练集上的损失： 0.000389189
# 在测试集上的损失： 0.00562016
# 在训练集上的损失： 0.000203995
# 在测试集上的损失： 0.00615514
# 在训练集上的损失： 7.03414e-05
# 在测试集上的损失： 0.00528027
# 在训练集上的损失： 6.57747e-05
# 在测试集上的损失： 0.00508537
# 在训练集上的损失： 9.18661e-05
# 在测试集上的损失： 0.0047961
# 在训练集上的损失： 6.54376e-05
# 在测试集上的损失： 0.00501932
# 在训练集上的损失： 0.000159213
# 在测试集上的损失： 0.00462248

# %%
from keras.layers import Input, Dense
from keras.models import Model

X_train = data_train[:, 1:]
y_train = data_train[:, 0]
X_test = data_test[:, 1:]
y_test = data_test[:, 0]

input_dim = X_train.shape[1]
hidden_1 = 1024
hidden_2 = 512
hidden_3 = 256
hidden_4 = 128
output_dim = 1
batch_size = 256
epochs = 10

X = Input(shape=[input_dim,])
h = Dense(hidden_1, activation='relu')(X)
h = Dense(hidden_2, activation='relu')(h)
h = Dense(hidden_3, activation='relu')(h)
h = Dense(hidden_4, activation='relu')(h)
Y = Dense(output_dim, activation='sigmoid')(h)

model = Model(X, Y)
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, shuffle=False)
y_pred = model.predict(X_test)
print('MSE Train:', model.evaluate(X_train, y_train, batch_size=batch_size))
print('MSE Test:', model.evaluate(X_test, y_test, batch_size=batch_size))
plt.plot(y_test, label='test')
plt.plot(y_pred, label='pred')
plt.legend()
plt.show()
# Out:
# Using TensorFlow backend.
# Epoch 1/10
# 33012/33012 [==============================] - 5s 147us/step - loss: 0.1268
# Epoch 2/10
# 33012/33012 [==============================] - 4s 128us/step - loss: 0.1227
# Epoch 3/10
# 33012/33012 [==============================] - 4s 128us/step - loss: 0.1080
# Epoch 4/10
# 33012/33012 [==============================] - 4s 127us/step - loss: 0.1086
# Epoch 5/10
# 33012/33012 [==============================] - 4s 127us/step - loss: 0.1058
# Epoch 6/10
# 33012/33012 [==============================] - 4s 128us/step - loss: 0.1042
# Epoch 7/10
# 33012/33012 [==============================] - 4s 128us/step - loss: 0.1053
# Epoch 8/10
# 33012/33012 [==============================] - 4s 128us/step - loss: 0.1065
# Epoch 9/10
# 33012/33012 [==============================] - 4s 128us/step - loss: 0.1087
# Epoch 10/10
# 33012/33012 [==============================] - 4s 128us/step - loss: 0.1075
# 33012/33012 [==============================] - 1s 33us/step
# MSE Train: 0.124026427783
# 8254/8254 [==============================] - 0s 31us/step
# MSE Test: 0.0254839933054
